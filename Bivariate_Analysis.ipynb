# %% [markdown]
# <a href="https://colab.research.google.com/github/RavaUnda/pythonLearning/blob/main/Bivariate_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.style.use('default')

# %%
df = pd.read_csv('EDA_Gold_Silver_prices.csv')
df
# Out:
#       Month  SilverPrice  GoldPrice
# 0    Mar-97       186.48   12619.24
# 1    Apr-97       170.65   12338.59
# 2    May-97       170.44   12314.94
# 3    Jun-97       169.96   12202.78
# 4    Jul-97       155.80   11582.07
# ..      ...          ...        ...
# 236  Nov-16      1175.45   83622.54
# 237  Dec-16      1115.72   78583.48
# 238  Jan-17      1151.15   81191.05
# 239  Feb-17      1203.35   82818.17
# 240  Mar-17      1162.15   81169.45
#
# [241 rows x 3 columns]

# %%
df.corr()
# Out:
#              SilverPrice  GoldPrice
# SilverPrice     1.000000   0.954256
# GoldPrice       0.954256   1.000000

# %%
sns.heatmap(data=df.corr(), cmap="Greens", annot=True, fmt='.4f')
# Out:
# <AxesSubplot:>

# %%
df[(df['Month'].apply(lambda x: x[-2:])=="08")]
# Out:
#       Month  SilverPrice  GoldPrice
# 130  Jan-08       632.29   35025.78
# 131  Feb-08       701.87   36642.46
# 132  Mar-08       775.49   39082.77
# 133  Apr-08       700.96   36416.00
# 134  May-08       718.20   37435.38
# 135  Jun-08       729.63   38087.88
# 136  Jul-08       773.80   40256.56
# 137  Aug-08       625.97   36026.85
# 138  Sep-08       555.58   37815.02
# 139  Oct-08       507.20   39235.79
# 140  Nov-08       483.55   37284.82
# 141  Dec-08       501.82   39696.27

# %%
df[(df['Month'].apply(lambda x: x[-2:])=="08")].corr()
# Out:
#              SilverPrice  GoldPrice
# SilverPrice     1.000000   0.009584
# GoldPrice       0.009584   1.000000

# %%
df2 = pd.read_csv('currencies.csv')
df2
# Out:
#          Currency  Chinese Yuan     Euro  Japanese Yen  U.K. Pound Sterling  \
# 0   July 01, 2016       9.29446  1.25367       143.645              1.05054
# 1   July 05, 2016       9.31515  1.25322       142.715              1.06143
# 2   July 06, 2016       9.31697  1.25834       140.540              1.07300
# 3   July 07, 2016       9.31315  1.25737       140.640              1.06911
# 4   July 08, 2016       9.31350  1.25797       140.510              1.07261
# 5   July 11, 2016       9.29403  1.25769       139.962              1.07050
# 6   July 12, 2016       9.31021  1.25490       143.369              1.05762
# 7   July 13, 2016       9.31350  1.25716       145.178              1.04680
# 8   July 14, 2016       9.30432  1.24695       144.895              1.05236
# 9   July 15, 2016       9.31532  1.25263       147.268              1.04242
# 10  July 18, 2016       9.30354  1.25652           NaN              1.04952
#
# ...

# %%
df2.corr()
# Out:
#                             Chinese Yuan      Euro  Japanese Yen  \
# Chinese Yuan                    1.000000  0.151596      0.117566
# Euro                            0.151596  1.000000     -0.645719
# Japanese Yen                    0.117566 -0.645719      1.000000
# U.K. Pound Sterling             0.108695  0.531150     -0.970308
# U.S. Dollar                     0.291582 -0.210587      0.210295
# Algerian Dinar                  0.815216  0.259964     -0.388099
# Australian Dollar               0.077983  0.331588     -0.582032
# Bahrain Dinar                   0.291926 -0.209926      0.209957
# Botswana Pula                   0.467693  0.469668     -0.627015
# Brazilian Real                  0.320508  0.383645     -0.641122
# Brunei Dollar                   0.499400  0.103766     -0.260258
# Canadian Dollar                -0.186643  0.638422     -0.662233
# Chilean Peso                    0.028821  0.242743     -0.809751
# ...

# %%
sns.heatmap(data=df2.corr(), cmap='Greens', annot=True, fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 52 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Currency                    11 non-null     object
#  1   Chinese Yuan                11 non-null     float64
#  2   Euro                        11 non-null     float64
#  3   Japanese Yen                10 non-null     float64
#  4   U.K. Pound Sterling         11 non-null     float64
#  5   U.S. Dollar                 11 non-null     float64
#  6   Algerian Dinar              9 non-null      float64
#  7   Australian Dollar           11 non-null     float64
#  8   Bahrain Dinar               11 non-null     float64
#  9   Botswana Pula               9 non-null      float64
#  10  Brazilian Real              11 non-null     float64
#  11  Brunei Dollar               10 non-null     float64
#  12  Canadian Dollar             10 non-null     float64
# ...

# %%
df2.corr()['Indian Rupee'].sort_values(ascending=False)
# Out:
# Indian Rupee                  1.000000
# Pakistani Rupee               0.991673
# Kuwaiti Dinar                 0.931099
# Botswana Pula                 0.930798
# Algerian Dinar                0.923232
# Australian Dollar             0.921475
# Nepalese Rupee                0.897655
# South African Rand            0.897567
# Nuevo Sol                     0.877833
# Bahrain Dinar                 0.873195
# Bolivar Fuerte                0.873170
# Rial Omani                    0.873151
# Saudi Arabian Riyal           0.873101
# Qatar Riyal                   0.873075
# U.S. Dollar                   0.872862
# U.A.E. Dirham                 0.872859
# Sri Lanka Rupee               0.872443
# Thai Baht                     0.868087
# Malaysian Ringgit             0.840498
# Mauritian Rupee               0.835943
# Icelandic Krona               0.825889
# Brunei Dollar                 0.798249
# Singapore Dollar              0.798249
# Russian Ruble                 0.790276
# ...

# %%
corr = df2[['Japanese Yen','U.S. Dollar','Australian Dollar','U.K. Pound Sterling','Chinese Yuan','Euro']].corr()
corr
# Out:
#                      Japanese Yen  U.S. Dollar  Australian Dollar  \
# Japanese Yen             1.000000     0.210295          -0.582032
# U.S. Dollar              0.210295     1.000000           0.607010
# Australian Dollar       -0.582032     0.607010           1.000000
# U.K. Pound Sterling     -0.970308    -0.042303           0.579213
# Chinese Yuan             0.117566     0.291582           0.077983
# Euro                    -0.645719    -0.210587           0.331588
#
#                      U.K. Pound Sterling  Chinese Yuan      Euro
# Japanese Yen                   -0.970308      0.117566 -0.645719
# U.S. Dollar                    -0.042303      0.291582 -0.210587
# Australian Dollar               0.579213      0.077983  0.331588
# U.K. Pound Sterling             1.000000      0.108695  0.531150
# Chinese Yuan                    0.108695      1.000000  0.151596
# Euro                            0.531150      0.151596  1.000000

# %%
sns.heatmap(data=corr, cmap='Greens', annot=True, fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Graded Assessment

# %%
df3 = pd.read_csv('nas.csv')
df3
# Out:
#             STUID        State  District Gender       Age  Category  \
# 0     26011001001  Maharashtra         1   Girl  13 years       3.0
# 1     26011001002  Maharashtra         1   Girl  15 years       3.0
# 2     26011001003  Maharashtra         1   Girl  14 years       3.0
# 3     26011001004  Maharashtra         1    Boy  13 years       3.0
# 4     26011001005  Maharashtra         1   Girl  14 years       3.0
# ...           ...          ...       ...    ...       ...       ...
# 8796  26141270036  Maharashtra        14    Boy  13 years       4.0
# 8797  26141270037  Maharashtra        14    Boy  13 years       3.0
# 8798  26141270038  Maharashtra        14    Boy  14 years       4.0
# 8799  26141270039  Maharashtra        14    Boy  13 years       4.0
# 8800  26141270040  Maharashtra        14    Boy  13 years       4.0
#
#       Same.language    Siblings Handicap      Father.edu  ...  \
# 0               2.0   1 sibling       No      Illiterate  ...
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8801 entries, 0 to 8800
# Data columns (total 64 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   STUID                   8801 non-null   int64
#  1   State                   8801 non-null   object
#  2   District                8801 non-null   int64
#  3   Gender                  8799 non-null   object
#  4   Age                     8569 non-null   object
#  5   Category                8232 non-null   float64
#  6   Same.language           8572 non-null   float64
#  7   Siblings                8801 non-null   object
#  8   Handicap                8304 non-null   object
#  9   Father.edu              8147 non-null   object
#  10  Mother.edu              7950 non-null   object
#  11  Father.occupation       7761 non-null   object
#  12  Mother.occupation       6626 non-null   object
#  13  Below.poverty           7347 non-null   object
# ...

# %%
df3.describe()
# Out:
#               STUID     District     Category  Same.language      Maths..  \
# count  8.801000e+03  8801.000000  8232.000000    8572.000000  4190.000000
# mean   2.608389e+10     8.255766     2.787293       1.102776    31.601532
# std    4.069188e+07     4.065476     1.146670       0.303684    14.734404
# min    2.601100e+10     1.000000     1.000000       1.000000     0.000000
# 25%    2.604207e+10     4.000000     2.000000       1.000000    22.030000
# 50%    2.609115e+10     9.000000     3.000000       1.000000    28.070000
# 75%    2.612121e+10    12.000000     4.000000       1.000000    36.840000
# max    2.614127e+10    14.000000     4.000000       2.000000    94.740000
#
#          Reading..    Science..     Social..
# count  4227.000000  4144.000000  4119.000000
# mean     55.404436    36.313272    40.502527
# std      23.279043    13.199105    14.479584
# min       0.000000     0.000000     0.000000
# 25%      35.575000    27.270000    30.610000
# ...

# %%
df3.corr()
# Out:
#                   STUID  District  Category  Same.language   Maths..  \
# STUID          1.000000  0.999926  0.183082      -0.084155 -0.064906
# District       0.999926  1.000000  0.184081      -0.083648 -0.064385
# Category       0.183082  0.184081  1.000000      -0.029298  0.044810
# Same.language -0.084155 -0.083648 -0.029298       1.000000 -0.038902
# Maths..       -0.064906 -0.064385  0.044810      -0.038902  1.000000
# Reading..      0.176836  0.176655  0.147099      -0.101234  0.351509
# Science..      0.088149  0.088583  0.083712      -0.071170  0.353656
# Social..       0.069857  0.070093  0.075718      -0.074421  0.560796
#
#                Reading..  Science..  Social..
# STUID           0.176836   0.088149  0.069857
# District        0.176655   0.088583  0.070093
# Category        0.147099   0.083712  0.075718
# Same.language  -0.101234  -0.071170 -0.074421
# Maths..         0.351509   0.353656  0.560796
# Reading..       1.000000   0.459859  0.413745
# ...

# %%
sns.heatmap(data=df3.corr(), cmap='Greens', annot=True, fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
df3['Mother.edu'].value_counts()
# Out:
# Secondary         2591
# Illiterate        2545
# Primary           2220
# Sr secondary       433
# Degree & above     161
# Name: Mother.edu, dtype: int64

# %%
df3['Siblings'].value_counts()
# Out:
# 2 siblings      2979
# 1 sibling       2726
# 3 siblings      1526
# 4+ siblings     1167
# Single child     403
# Name: Siblings, dtype: int64

# %%
def siblings(x):
    if '2' in x:
        return 2
    if '1' in x:
        return 1
    if '3' in x:
        return 3
    if '4' in x:
        return 4
    if x=='Single child':
        return 0

# %%
df3['Siblings_count'] = df3['Siblings'].apply(lambda x: siblings(x))
df3[['Siblings','Siblings_count']].head(20)
# Out:
#        Siblings  Siblings_count
# 0     1 sibling               1
# 1    3 siblings               3
# 2    3 siblings               3
# 3    3 siblings               3
# 4    2 siblings               2
# 5    2 siblings               2
# 6     1 sibling               1
# 7   4+ siblings               4
# 8    2 siblings               2
# 9   4+ siblings               4
# 10   2 siblings               2
# 11  4+ siblings               4
# 12   3 siblings               3
# 13   2 siblings               2
# 14   3 siblings               3
# 15   2 siblings               2
# 16   2 siblings               2
# 17  4+ siblings               4
# 18   3 siblings               3
# 19    1 sibling               1

# %%
df3.groupby('Mother.edu')['Siblings_count'].sum()
# Out:
# Mother.edu
# Degree & above     217
# Illiterate        5851
# Primary           4486
# Secondary         4806
# Sr secondary       706
# Name: Siblings_count, dtype: int64

# %%
df3.groupby(['Mother.edu','Siblings'])['Siblings_count'].sum()
# Out:
# Mother.edu      Siblings
# Degree & above  1 sibling         88
#                 2 siblings        72
#                 3 siblings        33
#                 4+ siblings       24
#                 Single child       0
# Illiterate      1 sibling        533
#                 2 siblings      1846
#                 3 siblings      1596
#                 4+ siblings     1876
#                 Single child       0
# Primary         1 sibling        689
#                 2 siblings      1542
#                 3 siblings      1251
#                 4+ siblings     1004
#                 Single child       0
# Secondary       1 sibling       1050
#                 2 siblings      1692
#                 3 siblings      1044
#                 4+ siblings     1020
#                 Single child       0
# Sr secondary    1 sibling        206
#                 2 siblings       264
#                 3 siblings       144
#                 4+ siblings       92
# ...

# %%
df3.groupby(['Mother.edu','Siblings'])['Siblings'].count()
# Out:
# Mother.edu      Siblings
# Degree & above  1 sibling         88
#                 2 siblings        36
#                 3 siblings        11
#                 4+ siblings        6
#                 Single child      20
# Illiterate      1 sibling        533
#                 2 siblings       923
#                 3 siblings       532
#                 4+ siblings      469
#                 Single child      88
# Primary         1 sibling        689
#                 2 siblings       771
#                 3 siblings       417
#                 4+ siblings      251
#                 Single child      92
# Secondary       1 sibling       1050
#                 2 siblings       846
#                 3 siblings       348
#                 4+ siblings      255
#                 Single child      92
# Sr secondary    1 sibling        206
#                 2 siblings       132
#                 3 siblings        48
#                 4+ siblings       23
# ...

# %%
df3.groupby(['Father.edu','Age'])['Science..'].sum()
# Out:
# Father.edu      Age
# Degree & above  12 years       327.27
#                 13 years      3136.36
#                 14 years      3072.74
#                 15 years        29.09
#                 16+ years       32.73
# Illiterate      11- years        0.00
#                 12 years      1045.45
#                 13 years      8507.26
#                 14 years     17589.10
#                 15 years      3809.12
#                 16+ years      927.27
# Primary         11- years      145.46
#                 12 years      1023.65
#                 13 years     13692.79
#                 14 years     20625.55
#                 15 years      3938.23
#                 16+ years     1294.56
# Secondary       11- years       89.09
#                 12 years      1410.94
#                 13 years     15952.72
#                 14 years     21896.36
#                 15 years      3287.28
#                 16+ years     1114.56
# Sr secondary    11- years        0.00
# ...
