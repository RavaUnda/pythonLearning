# %%
import numpy as np
import pandas as pd

# %%
# Read the dataset
df = pd.read_csv('C:/Users/u27571/Downloads/EDA_census_cleaned.csv')
df.head(5)
# Out:
#   TableName  State  Distt. AreaName Total/Rural/Urban population  AgeGroup  \
# 0     C2308      0       0    INDIA                        Total  All ages
# 1     C2308      0       0    INDIA                        Total       0-6
# 2     C2308      0       0    INDIA                        Total         7
# 3     C2308      0       0    INDIA                        Total         8
# 4     C2308      0       0    INDIA                        Total         9
#
#    Total_Population  Total_Male  Total_Female  Total_ill_Population  ...  \
# 0        1210854977   623270258     587584719             447216165  ...
# 1         164515253    85752254      78762999             164515253  ...
# 2          24826640    12903364      11923276               6748214  ...
# 3          26968373    14061937      12906436               4131414  ...
# 4          23424638    12214985      11209653               2491904  ...
#
#    Unnamed: 36  Unnamed: 37  Unnamed: 38  Unnamed: 39  Unnamed: 40  \
# ...

# %%
# Filter the DataFrame for females in the age group 20-24
filtered_df = df[(df['AgeGroup'] == '20-24')]
filtered_df.head(5)
# Out:
#     TableName  State  Distt.                 AreaName  \
# 15      C2308      0       0                    INDIA
# 44      C2308      0       0                    INDIA
# 73      C2308      0       0                    INDIA
# 102     C2308      1       0  State - JAMMU & KASHMIR
# 131     C2308      1       0  State - JAMMU & KASHMIR
#
#     Total/Rural/Urban population AgeGroup  Total_Population  Total_Male  \
# 15                         Total    20-24         111424222    57584693
# 44                         Rural    20-24          73835046    38138662
# 73                         Urban    20-24          37589176    19446031
# 102                        Total    20-24           1160913      603578
# 131                        Rural    20-24            827361      423292
#
#      Total_Female  Total_ill_Population  ...  Unnamed: 36  Unnamed: 37  \
# 15       53839529              18679492  ...          NaN          NaN
# ...

# %%
filtered_df.iloc[:10, :20]
# Out:
#     TableName  State  Distt.                  AreaName  \
# 15      C2308      0       0                     INDIA
# 44      C2308      0       0                     INDIA
# 73      C2308      0       0                     INDIA
# 102     C2308      1       0   State - JAMMU & KASHMIR
# 131     C2308      1       0   State - JAMMU & KASHMIR
# 160     C2308      1       0   State - JAMMU & KASHMIR
# 189     C2308      2       0  State - HIMACHAL PRADESH
# 218     C2308      2       0  State - HIMACHAL PRADESH
# 247     C2308      2       0  State - HIMACHAL PRADESH
# 276     C2308      3       0            State - PUNJAB
#
#     Total/Rural/Urban population AgeGroup  Total_Population  Total_Male  \
# 15                         Total    20-24         111424222    57584693
# 44                         Rural    20-24          73835046    38138662
# 73                         Urban    20-24          37589176    19446031
# ...

# %%
# Compute the literacy rate for all age groups of India
filter_litRate_df = df[df['AreaName'] == 'INDIA'].copy()
#selected_rows['UpdatedSalary'] = selected_rows['Salary'] * 1.1
filter_litRate_df['LiteracyRate'] = (filter_litRate_df['Total_Lit_Population'])/(filter_litRate_df['Total_Population'])
#filter_litRate_df.head(50)
filter_litRate_df.iloc[:29, :]
# Out:
#    TableName  State  Distt. AreaName Total/Rural/Urban population  \
# 0      C2308      0       0    INDIA                        Total
# 1      C2308      0       0    INDIA                        Total
# 2      C2308      0       0    INDIA                        Total
# 3      C2308      0       0    INDIA                        Total
# 4      C2308      0       0    INDIA                        Total
# 5      C2308      0       0    INDIA                        Total
# 6      C2308      0       0    INDIA                        Total
# 7      C2308      0       0    INDIA                        Total
# 8      C2308      0       0    INDIA                        Total
# 9      C2308      0       0    INDIA                        Total
# 10     C2308      0       0    INDIA                        Total
# 11     C2308      0       0    INDIA                        Total
# 12     C2308      0       0    INDIA                        Total
# ...

# %%
output_file = 'C:/Users/u27571/Downloads/output_file.xlsx'
# Write the DataFrame to an Excel file
filter_litRate_df.iloc[:29, :].to_excel(output_file, index=False)

# %%
# Compute the Female literacy rate for all age groups of all states
df['Female_LiteracyRate'] = (df['Female_lit'])/(df['Total_Female'])
#filter_litRate_df.head(50)
#filter_litRate_df.iloc[:29, :]
output_file = 'C:/Users/u27571/Downloads/output_file_2.xlsx'
# Write the DataFrame to an Excel file
df.iloc[:, :].to_excel(output_file, index=False)
